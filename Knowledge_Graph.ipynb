# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaGilisho/Natural-Language-Processing-with-Python-for-SEOs/blob/main/Knowledge_Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install advertools

# %%
import advertools as adv
print(adv.__version__)
# Out:
# 0.13.2

# %%
sitemap_url = "https://www.searchenginejournal.com/sitemap_index.xml" #@param {type:"string"}

# %% [markdown]
# Let's download the sitemap index

# %%
df = adv.sitemap_to_df(sitemap_url)
# Out:
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap3.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap2.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap4.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap8.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap10.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap12.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap13.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap15.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap14.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap16.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap5.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap7.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap17.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap6.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap18.xml
# INFO:root:Getting https://www.searchenginejournal.com/page-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap23.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap22.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap9.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap21.xml
# INFO:root:Getting https://www.searchenginejournal.com/seo-tools-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap11.xml
# INFO:root:Getting https://www.searchenginejournal.com/google-algo-history-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/link-building-guide-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/seo-guide-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/local-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/content-kpis-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/ppc-guide-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/holiday-marketing-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/social-media-guide-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/ecommerce-guide-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/on-page-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/search-engines-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/seo-audit-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/content-marketing-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/enterprise-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/law-firm-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/keyword-research-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/facebook-ads-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/category-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/wordpress-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/technical-seo-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/ranking-factors-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/google-eat-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/author-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/news-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/author-sitemap2.xml
# INFO:root:Getting https://www.searchenginejournal.com/core-web-vitals-sitemap.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap19.xml
# INFO:root:Getting https://www.searchenginejournal.com/post-sitemap20.xml

# %% [markdown]
# One cool feature in the package is that it downloaded all the linked sitemaps in the index and we get a nice dataframe
#
# ---

# %%
# %load_ext google.colab.data_table

# %%
df
# Out:
#                                                      loc  \
# 0                   https://www.searchenginejournal.com/
# 1      https://www.searchenginejournal.com/microsoft-...
# 2      https://www.searchenginejournal.com/website-us...
# 3      https://www.searchenginejournal.com/the-5-step...
# 4      https://www.searchenginejournal.com/online-adv...
# ...                                                  ...
# 23057  https://www.searchenginejournal.com/google-sea...
# 23058  https://www.searchenginejournal.com/google-off...
# 23059  https://www.searchenginejournal.com/ppc-protec...
# 23060  https://www.searchenginejournal.com/google-dis...
# 23061  https://www.searchenginejournal.com/why-run-re...
#
#                         lastmod  \
# 0     2023-02-14 21:41:45+00:00
# 1                           NaT
# 2                           NaT
# 3                           NaT
# 4                           NaT
# ...                         ...
# 23057 2021-10-26 21:55:17+00:00
# 23058 2021-10-26 21:55:24+00:00
# 23059 2021-10-27 11:51:20+00:00
# 23060 2021-10-27 11:52:14+00:00
# 23061 2021-10-27 11:52:42+00:00
#
#                                                  sitemap  \
# 0      https://www.searchenginejournal.com/post-sitem...
# 1      https://www.searchenginejournal.com/post-sitem...
# 2      https://www.searchenginejournal.com/post-sitem...
# 3      https://www.searchenginejournal.com/post-sitem...
# 4      https://www.searchenginejournal.com/post-sitem...
# ...                                                  ...
# 23057  https://www.searchenginejournal.com/post-sitem...
# 23058  https://www.searchenginejournal.com/post-sitem...
# 23059  https://www.searchenginejournal.com/post-sitem...
# 23060  https://www.searchenginejournal.com/post-sitem...
# 23061  https://www.searchenginejournal.com/post-sitem...
#
#           sitemap_last_modified  sitemap_size_mb  \
# 0     2023-02-15 06:05:50+00:00         0.135637
# 1     2023-02-15 06:05:50+00:00         0.135637
# 2     2023-02-15 06:05:50+00:00         0.135637
# 3     2023-02-15 06:05:50+00:00         0.135637
# 4     2023-02-15 06:05:50+00:00         0.135637
# ...                         ...              ...
# 23057 2023-02-15 07:36:13+00:00         0.640600
# 23058 2023-02-15 07:36:13+00:00         0.640600
# 23059 2023-02-15 07:36:13+00:00         0.640600
# 23060 2023-02-15 07:36:13+00:00         0.640600
# 23061 2023-02-15 07:36:13+00:00         0.640600
#
#                          download_date     image  \
# 0     2023-02-15 07:36:09.265265+00:00       NaN
# 1     2023-02-15 07:36:09.265265+00:00       NaN
# 2     2023-02-15 07:36:09.265265+00:00       NaN
# 3     2023-02-15 07:36:09.265265+00:00       NaN
# 4     2023-02-15 07:36:09.265265+00:00       NaN
# ...                                ...       ...
# 23057 2023-02-15 07:36:13.884760+00:00  \n\t\t\t
# 23058 2023-02-15 07:36:13.884760+00:00  \n\t\t\t
# 23059 2023-02-15 07:36:13.884760+00:00  \n\t\t\t
# 23060 2023-02-15 07:36:13.884760+00:00  \n\t\t\t
# 23061 2023-02-15 07:36:13.884760+00:00  \n\t\t\t
#
#                                                image_loc news  \
# 0                                                    NaN  NaN
# 1                                                    NaN  NaN
# 2                                                    NaN  NaN
# 3                                                    NaN  NaN
# 4                                                    NaN  NaN
# ...                                                  ...  ...
# 23057  https://cdn.searchenginejournal.com/wp-content...  NaN
# 23058  https://cdn.searchenginejournal.com/wp-content...  NaN
# 23059  https://cdn.searchenginejournal.com/wp-content...  NaN
# 23060  https://cdn.searchenginejournal.com/wp-content...  NaN
# 23061  https://cdn.searchenginejournal.com/wp-content...  NaN
#
#       news_publication publication_name publication_language  \
# 0                  NaN              NaN                  NaN
# 1                  NaN              NaN                  NaN
# 2                  NaN              NaN                  NaN
# 3                  NaN              NaN                  NaN
# 4                  NaN              NaN                  NaN
# ...                ...              ...                  ...
# 23057              NaN              NaN                  NaN
# 23058              NaN              NaN                  NaN
# 23059              NaN              NaN                  NaN
# 23060              NaN              NaN                  NaN
# 23061              NaN              NaN                  NaN
#
#       news_publication_date news_title
# 0                       NaN        NaN
# 1                       NaN        NaN
# 2                       NaN        NaN
# 3                       NaN        NaN
# 4                       NaN        NaN
# ...                     ...        ...
# 23057                   NaN        NaN
# 23058                   NaN        NaN
# 23059                   NaN        NaN
# 23060                   NaN        NaN
# 23061                   NaN        NaN
#
# [23062 rows x 14 columns]

# %% [markdown]
# We have 1550 articles

# %%
df[df["lastmod"] > '2023-01-01']
# Out:
#                                                      loc  \
# 0                   https://www.searchenginejournal.com/
# 15245  https://www.searchenginejournal.com/ranking-fa...
# 15246  https://www.searchenginejournal.com/webinar-lp...
# 15247  https://www.searchenginejournal.com/enterprise...
# 15248  https://www.searchenginejournal.com/seo-trends...
# ...                                                  ...
# 20050  https://www.searchenginejournal.com/author/dav...
# 20051  https://www.searchenginejournal.com/author/ahr...
# 20052  https://www.searchenginejournal.com/author/kri...
# 20053  https://www.searchenginejournal.com/author/gre...
# 20054  https://www.searchenginejournal.com/author/kay...
#
#                         lastmod  \
# 0     2023-02-14 21:41:45+00:00
# 15245 2023-01-10 12:11:49+00:00
# 15246 2023-01-12 14:07:16+00:00
# 15247 2023-01-17 09:51:56+00:00
# 15248 2023-01-17 09:53:23+00:00
# ...                         ...
# 20050 2023-01-09 13:24:25+00:00
# 20051 2023-01-05 04:40:24+00:00
# 20052 2023-01-03 22:22:58+00:00
# 20053 2023-01-03 16:52:35+00:00
# 20054 2023-01-01 09:02:39+00:00
#
#                                                  sitemap  \
# 0      https://www.searchenginejournal.com/post-sitem...
# 15245  https://www.searchenginejournal.com/page-sitem...
# 15246  https://www.searchenginejournal.com/page-sitem...
# 15247  https://www.searchenginejournal.com/page-sitem...
# 15248  https://www.searchenginejournal.com/page-sitem...
# ...                                                  ...
# 20050  https://www.searchenginejournal.com/author-sit...
# 20051  https://www.searchenginejournal.com/author-sit...
# 20052  https://www.searchenginejournal.com/author-sit...
# 20053  https://www.searchenginejournal.com/author-sit...
# 20054  https://www.searchenginejournal.com/author-sit...
#
#           sitemap_last_modified  sitemap_size_mb  \
# 0     2023-02-15 06:05:50+00:00         0.135637
# 15245 2023-02-15 06:05:39+00:00         0.017887
# 15246 2023-02-15 06:05:39+00:00         0.017887
# 15247 2023-02-15 06:05:39+00:00         0.017887
# 15248 2023-02-15 06:05:39+00:00         0.017887
# ...                         ...              ...
# 20050 2023-02-15 06:05:42+00:00         0.126793
# 20051 2023-02-15 06:05:42+00:00         0.126793
# 20052 2023-02-15 06:05:42+00:00         0.126793
# 20053 2023-02-15 06:05:42+00:00         0.126793
# 20054 2023-02-15 06:05:42+00:00         0.126793
#
#                          download_date     image  \
# 0     2023-02-15 07:36:09.265265+00:00       NaN
# 15245 2023-02-15 07:36:11.578677+00:00  \n\t\t\t
# 15246 2023-02-15 07:36:11.578677+00:00  \n\t\t\t
# 15247 2023-02-15 07:36:11.578677+00:00  \n\t\t\t
# 15248 2023-02-15 07:36:11.578677+00:00  \n\t\t\t
# ...                                ...       ...
# 20050 2023-02-15 07:36:13.266983+00:00       NaN
# 20051 2023-02-15 07:36:13.266983+00:00       NaN
# 20052 2023-02-15 07:36:13.266983+00:00       NaN
# 20053 2023-02-15 07:36:13.266983+00:00       NaN
# 20054 2023-02-15 07:36:13.266983+00:00       NaN
#
#                                                image_loc news  \
# 0                                                    NaN  NaN
# 15245  https://cdn.searchenginejournal.com/wp-content...  NaN
# 15246  https://cdn.searchenginejournal.com/wp-content...  NaN
# 15247  https://cdn.searchenginejournal.com/wp-content...  NaN
# 15248  https://cdn.searchenginejournal.com/wp-content...  NaN
# ...                                                  ...  ...
# 20050                                                NaN  NaN
# 20051                                                NaN  NaN
# 20052                                                NaN  NaN
# 20053                                                NaN  NaN
# 20054                                                NaN  NaN
#
#       news_publication publication_name publication_language  \
# 0                  NaN              NaN                  NaN
# 15245              NaN              NaN                  NaN
# 15246              NaN              NaN                  NaN
# 15247              NaN              NaN                  NaN
# 15248              NaN              NaN                  NaN
# ...                ...              ...                  ...
# 20050              NaN              NaN                  NaN
# 20051              NaN              NaN                  NaN
# 20052              NaN              NaN                  NaN
# 20053              NaN              NaN                  NaN
# 20054              NaN              NaN                  NaN
#
#       news_publication_date news_title
# 0                       NaN        NaN
# 15245                   NaN        NaN
# 15246                   NaN        NaN
# 15247                   NaN        NaN
# 15248                   NaN        NaN
# ...                     ...        ...
# 20050                   NaN        NaN
# 20051                   NaN        NaN
# 20052                   NaN        NaN
# 20053                   NaN        NaN
# 20054                   NaN        NaN
#
# [436 rows x 14 columns]

# %%
df[df["lastmod"] > '2023-01-01'][["loc", "lastmod"]].to_csv("latest_articles.csv", index=False)

# %% [markdown]
# We can export this list to a csv. I will include only the URL and last modification time stamp.

# %% [markdown]
# ##Extract headlines from the URLs
#
# The advertools library has a function to break URLs, but we will do it manually to get familiar with the process.

# %%
example_url="https://www.searchenginejournal.com/google-be-careful-relying-on-3rd-parties-to-render-website-content/376547/" #@param {type:"string"}

# %%
from urllib.parse import urlparse
import re

# %%
u = urlparse(example_url)

# %%
u
# Out:
# ParseResult(scheme='https', netloc='www.searchenginejournal.com', path='/google-be-careful-relying-on-3rd-parties-to-render-website-content/376547/', params='', query='', fragment='')

# %% [markdown]
# Here we get a named tuple, ```ParseResult```, with a breakdown of the URL components.
#
# We are interested in the ```path```.
#
# We are going to use a simple regex to split it by / and - characters

# %%
slug = re.split("[/-]", u.path)

slug
# Out:
# ['',
#  'google',
#  'be',
#  'careful',
#  'relying',
#  'on',
#  '3rd',
#  'parties',
#  'to',
#  'render',
#  'website',
#  'content',
#  '376547',
#  '']

# %% [markdown]
# Next, we can convert it back to a string

# %%
headline = " ".join(slug)
headline
# Out:
# ' google be careful relying on 3rd parties to render website content 376547 '

# %% [markdown]
# The slugs contain a page identifier that is useless for us. We will remove with a regex

# %%
headline = re.sub("\d{6}", "",headline)
headline
# Out:
# ' google be careful relying on 3rd parties to render website content  '

# %% [markdown]
# Strip whitespace at the borders

# %%
headline = headline.strip()
headline
# Out:
# 'google be careful relying on 3rd parties to render website content'

# %%
if re.match("author|category", "autho stephen kenwright"):
  print("Ok")

# %% [markdown]
# We can convert this code to a function and create a new column in our dataframe

# %%
def get_headline(url):

  u = urlparse(url)

  if len(u.path) > 1:

    slug = re.split("[/-]", u.path)

    new_headline = re.sub("\d{6}", ""," ".join(slug)).strip()

    #skip author and category pages
    if not re.match("author|category", new_headline):
      return new_headline

  return ""

# %%
#let's test it
get_headline(example_url)
# Out:
# 'google be careful relying on 3rd parties to render website content'

# %%
import pandas as pd

#skip the home page and headers
new_df = pd.read_csv("latest_articles.csv", names=["url", "lastmod"], skiprows=2)

# %%
new_df
# Out:
#                                                    url  \
# 0    https://www.searchenginejournal.com/ranking-fa...
# 1    https://www.searchenginejournal.com/webinar-lp...
# 2    https://www.searchenginejournal.com/enterprise...
# 3    https://www.searchenginejournal.com/seo-trends...
# 4    https://www.searchenginejournal.com/search-eng...
# ..                                                 ...
# 430  https://www.searchenginejournal.com/author/dav...
# 431  https://www.searchenginejournal.com/author/ahr...
# 432  https://www.searchenginejournal.com/author/kri...
# 433  https://www.searchenginejournal.com/author/gre...
# 434  https://www.searchenginejournal.com/author/kay...
#
#                        lastmod
# 0    2023-01-10 12:11:49+00:00
# 1    2023-01-12 14:07:16+00:00
# 2    2023-01-17 09:51:56+00:00
# 3    2023-01-17 09:53:23+00:00
# 4    2023-01-17 11:23:50+00:00
# ..                         ...
# 430  2023-01-09 13:24:25+00:00
# 431  2023-01-05 04:40:24+00:00
# 432  2023-01-03 22:22:58+00:00
# 433  2023-01-03 16:52:35+00:00
# 434  2023-01-01 09:02:39+00:00
#
# [435 rows x 2 columns]

# %% [markdown]
# Let's create a new column named headline

# %%
new_df["url"]
# Out:
# 0      https://www.searchenginejournal.com/ranking-fa...
# 1      https://www.searchenginejournal.com/webinar-lp...
# 2      https://www.searchenginejournal.com/enterprise...
# 3      https://www.searchenginejournal.com/seo-trends...
# 4      https://www.searchenginejournal.com/search-eng...
#                              ...
# 430    https://www.searchenginejournal.com/author/dav...
# 431    https://www.searchenginejournal.com/author/ahr...
# 432    https://www.searchenginejournal.com/author/kri...
# 433    https://www.searchenginejournal.com/author/gre...
# 434    https://www.searchenginejournal.com/author/kay...
# Name: url, Length: 435, dtype: object

# %% [markdown]
# this will run the function on each URL

# %%
new_df["url"].apply(lambda x: get_headline(x))
# Out:
# 0                                        ranking factors
# 1      webinar lp enterprise seo 7 use cases to level...
# 2                                   enterprise seo guide
# 3                                        seo trends 2023
# 4                                         search engines
#                              ...
# 430
# 431
# 432
# 433
# 434
# Name: url, Length: 435, dtype: object

# %%
new_df["headline"] = new_df["url"].apply(lambda x: get_headline(x))

# %%
new_df
# Out:
#                                                    url  \
# 0    https://www.searchenginejournal.com/ranking-fa...
# 1    https://www.searchenginejournal.com/webinar-lp...
# 2    https://www.searchenginejournal.com/enterprise...
# 3    https://www.searchenginejournal.com/seo-trends...
# 4    https://www.searchenginejournal.com/search-eng...
# ..                                                 ...
# 430  https://www.searchenginejournal.com/author/dav...
# 431  https://www.searchenginejournal.com/author/ahr...
# 432  https://www.searchenginejournal.com/author/kri...
# 433  https://www.searchenginejournal.com/author/gre...
# 434  https://www.searchenginejournal.com/author/kay...
#
#                        lastmod  \
# 0    2023-01-10 12:11:49+00:00
# 1    2023-01-12 14:07:16+00:00
# 2    2023-01-17 09:51:56+00:00
# 3    2023-01-17 09:53:23+00:00
# 4    2023-01-17 11:23:50+00:00
# ..                         ...
# 430  2023-01-09 13:24:25+00:00
# 431  2023-01-05 04:40:24+00:00
# 432  2023-01-03 22:22:58+00:00
# 433  2023-01-03 16:52:35+00:00
# 434  2023-01-01 09:02:39+00:00
#
#                                               headline
# 0                                      ranking factors
# 1    webinar lp enterprise seo 7 use cases to level...
# 2                                 enterprise seo guide
# 3                                      seo trends 2023
# 4                                       search engines
# ..                                                 ...
# 430
# 431
# 432
# 433
# 434
#
# [435 rows x 3 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   url       435 non-null    object
#  1   lastmod   435 non-null    object
#  2   headline  435 non-null    object
# dtypes: object(3)
# memory usage: 10.3+ KB

# %% [markdown]
# ## Extracting named entities

# %% [markdown]
# Let's get our list of headlines and convert to a single text document

# %%
new_df["headline"].tolist()[:10]
# Out:
# ['ranking factors',
#  'webinar lp enterprise seo 7 use cases to level up website optimization with website intelligence',
#  'enterprise seo guide',
#  'seo trends 2023',
#  'search engines',
#  'advertise',
#  'ppc trends 2023',
#  'webinar lp smarter ads 5 cost efficient ways to get higher return on paid media',
#  'careers',
#  'webinar lp how to predict your seo success a 5 step formula to help you win']

# %%
text = "\n".join([x for x in new_df["headline"].tolist() if len(x) > 0])

# %%
with open("text.txt", "w") as f:
  f.write(text)

# %%
print(text)
# Out:
# ranking factors
# webinar lp enterprise seo 7 use cases to level up website optimization with website intelligence
# enterprise seo guide
# seo trends 2023
# search engines
# advertise
# ppc trends 2023
# webinar lp smarter ads 5 cost efficient ways to get higher return on paid media
# careers
# webinar lp how to predict your seo success a 5 step formula to help you win
# state of seo
# contact
# seo
# about
# webinar lp 5 ways to combine seo sem for more effective marketing roi
# b2b google ad campaigns
# creative intelligence advertising podcast
# how to access google analytics api via python
# helpful content algorithm
# popular plugin for woocommerce patches vulnerability
# wordpress popup maker vulnerability
# linkedin announces 7 updates coming in 2023
# instagram chief lists top 3 priorities for 2023
# chatgpt examples
# youtube predicts what will go viral in 2023
# how to create social media strategy
# google updates article type structured data guidance
# meta fined 414m for eu privacy law violations
# how to use slack
# what to tweet ideas
# microsoft bing with chatcpt reportedly launching in march
# best free online seo training courses
# market intelligence
# sem strategy in 2023 more ahead with your year in review
# google recommends multiple date signals on webpages
# content marketing statistics
# google answers how long it takes to recover from algorithmic penalty
# google calm a new language model technology
# google search patents 2020 roundup
# google patent related entities media
# google patents are not always used in search
# google algorithm patent
# google patent interpret queries
# google search patent update december 18 2020
# how e a t works google patents
# google search patent update january 29 2020
# latest google patents of interest february 25 2020
# two latest google patents of interest november 6 2020
# google patents first half 2020
# google patent for modifying results based on generic ratings
# latest google patents of interest march 11 2020
# google patents october 13 2020
# google patent rewriting queries intent
# google patents future proofing your seo podcast
# google quality algorithm
# googles patent application analysis 1827
# google search patent update february 18 2020
# google natural link patent
# google query completions patent
# google wants know times according new patent
# google patents watch time as a search ranking factor
# annotation text links
# pagerank patent
# chatgpts popularity boosts openais value to 29 billion
# social media marketing predictions for 2023
# pillar page
# social media manager skills
# social media career
# social media marketing examples
# chrome canary features for technical seo
# ai for seo
# keyword mapping beginners guide
# instagram marketing guide
# how to dominate ecommerce this year
# how to get google to index your site quickly
# apple ad network gives marketers a new opportunity
# microsoft exploring use of chatgpt in word powerpoint outlook
# top social media influencers
# four day work week pilot early challenges an sej case study part 1
# how to create a survey quickly google forms microsoft word
# faq schema guide
# advertisers react to googles remove redundant keywords update
# how to identify site quality for link building
# how to build hundreds of links in a month
# landing page best practices webinar
# sms marketing trends webinar
# marketing strategies ideas webinar
# sms holiday marketing tips
# site quality for link building
# keyword research conductor tips
# creating paid social campaigns that convert webinar recap
# website health check technical seo tips tools webinar recap
# 15 sms marketing trends every local business marketer needs to know
# saas marketers the paid social approach that works for you
# state of seo the top opportunities risks for the next 12 months
# create optimize content higher google rankings webinar recap
# free seo tools ahrefs spa
# how to create wordpress ecommerce website
# microsoft reportedly planning a 10 billion investment in openai
# youtubes new partner program terms what you need to know
# content marketing funnel
# youtube adsense how to get started
# 301 redirect pagerank
# revamping website search impact
# google product reviews linking to multiple sellers may get boost
# openai chatgpt update
# goals vs kpis
# paid media types examples
# openai chatgpt professional
# outrank competitors ai content contentedge spcs
# call tracking for google ads seo convert leads faster webinar
# scale enterprise seo ecommerce
# 3 ways seo has changed this year what it means for you
# how to create linkable content
# customer generation secrets to outperform your competition
# 9 best practices for sms marketing this year
# site migration seo common mistakes that hurt rankings
# drive ecommerce traffic conversions 3 secrets amazon doesnt want you to know
# why first party data should lead your organic search strategy
# integrate product performance marketing
# local seo tips experts miss webinar recap
# earn links organically resist dark side webinar
# drive higher lead quality seo user intent
# prioritize seo business impact
# proven local marketing strategies to drive customer experience roi
# increase ecommerce organic traffic with automation
# how to build links for ecommerce affiliate sites webinar recap
# improve lead quality follow up webinar
# getting the most of agencies webinar
# how to track customers revenue from seo in your crm
# revisiting word count
# microsoft announces store ads other updates
# content plan template
# key insights from tiktok in the whats next 2023 trend report
# how to use pinterest for ecommerce
# google cloud launches new ai tools for retailers
# google chrome team shares tips for optimizing core web vitals
# online review statistics
# what is chatgpt
# sitelinks what are they how do you get them
# downloadable content strategy template
# googles john mueller move javascript below html head
# will chatgpt take your job
# twitter cuts off access to third party apps
# microsoft openai bring ai models to developers worldwide
# conversion funnel how to optimize customer journey
# guide enterprise seo strategy saas brands
# when is the right time to do a content audit for seo
# youtube launches new analytics custom shorts thumbnails
# twitters revenue down 40 as 500 top advertisers pull out
# website optimization enterprise seo webinar
# google removes embedded podcasts from search results
# examples contact us pages
# newsjacking examples
# linkedin fastest growing jobs
# automattic announces blaze ad network of millions of wordpress com tumblr sites
# interactive content types engage your audience
# duda announces woorank integration
# openai gpt 4
# video marketing an in depth guide for every business owner
# googles penguin algorithm really research
# googles founders return how chatgpt is changing search
# chatgpt pro early access users share their thoughts
# google ads down for advertisers google confirms
# tiktok staff can decide what goes viral
# social media posts real estate inspiration
# yoast seo 20
# youtube seo video optimization
# microsoft openai extend deal to make ai accessible to everyone
# how to avoid plagiarism
# linkedins new feature can help you find must read newsletters
# mobile seo optimize devices webceo spcs
# google merchant listing experiences tips for optimizing product pages
# states vs google a closer look at the dojs antitrust lawsuit
# microsoft ceo every app is going to be an ai app
# twitter rolls out search keywords ads to all advertisers
# wayback machine 5 alternatives to try
# facebook marketing beginners guide
# google optimize discontinued what businesses need to know
# linkedin data what businesses advertisers need to know
# google discover follow feed guideline update
# meta reinstates trump to facebook instagram
# sustaining saas brand organic channel recession
# where are the advertisers leaving twitter super bowl
# 7 content marketing best practices in 2023
# top youtube trending videos ads
# is chatgpt use of web content fair
# want entrepreneur 72375
# most emotionally engaging christmas ads
# flywheel
# twitter amazon link add items shopping cart single tweet
# john lewis 2019 christmas advert
# is a super bowl ad the equivalent of lighting money on fire
# pagespeed insights showing more field data
# coke and oreo battle of the legacy brands 57969
# coronavirus response videos brands
# super bowl ads marketing takeaways
# will facebook instant articles affect seo
# interview andrew pincock trafficado pubcon 74887
# seo target multiple cities
# wordpress admin ui is bad
# content writing tips from experts
# ovh data center fire darkens thousands of sites worldwide
# 7 ways to create authoritative content even if youre just starting out
# the future of online video advertising for online marketers 5092
# google releases adwords search funnels 19301
# identity custom user experiences podcast
# master visual content marketing
# linkedin matched audiences
# bing public perception up 51706
# leapfish instant search results as you type 8376
# clickbooth launches new content monetization widget revcontent 77559
# earn useful marketing build google safe links pubcon 2014
# snapchat new lenses let users play ar games
# supermetric excel powerful marketing reporting tool
# snapchat partners square introduce snapcash money sending service
# brand stand controversial political issues
# diane von furstenberg introduces high fashion frames google glass
# affiliate management days march 19 20 in san francisco 93855
# seo the future of search results 64994
# pinterest messaging arrives send private messages pinterest users
# step step seo strategy development interview steve wiideman
# youtube is developing a tool that creates 6 second ads automatically
# introducing sejs new column ask an seo
# pinterest bringing guided search mobile apps desktop users
# youtube launch new app specifically content creators
# matt cutts resigns google confirms hes staying us digital service
# bing scroogled google 53183
# times brands went viral wrong reasons
# google introduces new features automatically generate movies travelogues
# chris boggs google hummingbird pubcon 74915
# google plus post display ads 81223
# google launches interactive html5 ad website builder 71829
# google adsense explains content policy
# google confirms penguin 3 0 update heres reaction far
# podium is a game changer for collecting improving reviews
# google makes image ads easier ready creatives 71239
# new information leaked googles favoriting service called google stars
# yahoo news company acquires vizify removes facebook google log options 93827
# 4 reasons why employers should invest in building the authorrank of employees 51837
# cpmeo and gazing time will be the future of web advertising 65714
# twitter officially introduces buy button
# everything need know googles winter wonderlabs 78045
# tips content marketing influencers interview drew hendricks 83013
# rocco facebook advertising
# sejsummit santa monica 2016 recap search aso human connection
# five new adwords tools that can help you move the needle 26175
# snapchats popular feature isnt actually snaps
# adwords ad serving myth busting 11126
# search ad display remarketing is now out of beta 63198
# snapchat deliver bite sized pieces news entertainment media publishers
# pinterest announces improvements user experience guided search custom categories
# build productive habits workday
# chatgpt search neeva ai podcast
# twitter introduces new appeal process for suspended accounts
# scaling content production
# google tf idf
# google moved on from 200 ranking signals
# yandex search ranking factors
# googles gary illyes answers your seo questions on linkedin
# new google ads feature account level negative keywords
# openai releases tool to detect ai written content
# content strategy framework
# affiliate marketing content creators
# 10 affiliate marketing tracking software platforms
# forecast seo campaign formula webinar
# keyword research topic clustering recap
# wordpress security guide
# seo algorithm predictions 2023 recap
# seo financial services brands
# google business profile financial vertical
# yelp trust safety report
# google seo tips for news articles lastmod tag separate sitemaps
# google updates search console video indexing report
# bing revamps crawl system to enhance search engine efficiency
# openai launches chatgpt plus for 20 per month
# google launching passkey support for android chrome
# chatgpt update improved math capabilities
# google john mueller disavow tool
# marketing attribution
# lead generation how to get started
# yandex data leak
# googles mueller slams negative seo link disavow companies
# response to chatgpt plus
# email marketing an in depth guide
# disadvantages chatgpt content
# googles q4 report the challenges opportunities for marketers
# affiliate marketing programs
# how to block chatgpt from using your website content
# twitter ad revenue sharing
# google says ai generated content is against guidelines
# chatgpt content detect ai
# google headings with hierarchical structure an awesome idea
# google updates structured data guidance to clarify supported formats
# how to optimize website architecture for seo
# ux design seo
# chatgpt harness ai marketing
# microsoft bing chatgpt 5 possible features at launch
# youtube shorts monetization how revenue sharing works
# getty images sues stability ai for copyright infringement
# ways seos are using chatgpt right now
# what is a sitemap
# rendering seo introduction
# chrome 110 web share api
# from competitors to partners conductor acquires searchmetrics
# google ceo confirms ai features coming to search soon
# fix seo keyword cannibalizations dinorank spa
# googles new ai powered features search just got smarter
# google maps brings a new level of interactivity to your journey
# google launches ai powered contextual translations
# microsoft announces chatgpt capabilities coming to bing
# sitelinks dos donts
# microsoft advertising launches audience segments for valentines day
# google ai content in search results
# link blogging strategies 2023 podcast
# googles expert advice on seo troubleshooting with devtools
# alternative search engines list
# google bard training data
# tiktok introduces more ways to boost organic content with promote
# global marketing day feb 16 the 24 hour semrush conference you just cant miss spa
# neevaai now available worldwide
# connect paid organic search webinar
# enterprise seo website intelligence recap
# google on use of product structured data for a services business
# linkedin data 91 of applicants want salary range in job posting
# techniques customer reviews local business
# scale ppc google ads podcast
# google ads launches new ctv advertising features
# youtubes new updates help creators engage analyze data
# improve seo topic clusters iquanti spa
# seo tools excel
# seo tools competitive analysis
# seo tools link building tools
# seo tools keyword research tools
# seo tools reporting
# content marketing kpis metrics
# social media who has the most subscribers on youtube
# social media tweet ideas for businesses
# social media linkedin advertising beginners guide
# holiday marketing holiday marketing calendar template
# on page seo optimize meta description
# on page seo title tag optimization
# on page seo header tags
# on page seo image optimization
# on page seo internal external links ctr
# search engines website indexing
# keyword research free tools
# ranking factors domain authority
# ranking factors google search console
# ranking factors domain name
# ranking factors google analytics
# technical seo redirects

# %% [markdown]
# ## Introducing Spacy
#
# https://spacy.io/usage/spacy-101
#
# https://spacy.io/usage/examples
#
# https://spacy.io/api/annotation

# %%
# !pip install spacy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.8/dist-packages (3.4.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.10.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (23.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy) (8.1.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy) (2.0.1)

# %%
import spacy
from spacy import displacy
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# !python -m spacy download en
# !python -m spacy download en_core_web_sm
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-15 07:38:07.582939: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-15 07:38:07.583109: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-02-15 07:38:07.583136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-15 07:38:09.315436: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 26.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.4.1) (3.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.12)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.25.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (57.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.11.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (6.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.21.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ranking factors</br>webinar lp enterprise seo
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  use cases to level up website optimization with website intelligence</br>enterprise seo guide</br>seo trends
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>search engines</br>advertise</br>ppc trends
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>webinar lp smarter ads
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  cost efficient ways to get higher return on paid media</br>careers</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     webinar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lp how to predict your seo success a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  step formula to help you win</br>state of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br>contact</br>seo</br>about</br>webinar lp
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ways to combine seo sem for more effective marketing roi</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     b2b google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ad campaigns</br>creative intelligence advertising podcast</br>how to access google analytics api via python</br>helpful content algorithm</br>popular plugin for woocommerce patches vulnerability</br>wordpress popup maker vulnerability</br>linkedin announces
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  updates coming in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>instagram chief lists top
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  priorities for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>chatgpt examples</br>youtube predicts what will go viral in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>how to create social media strategy</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  updates article type structured data guidance</br>meta fined
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     414
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# m for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  privacy law violations</br>how to use slack</br>what to tweet ideas</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bing with chatcpt reportedly launching in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     march
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>best free online seo training courses</br>market intelligence</br>sem strategy in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2023
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more ahead with your year in review</br>google recommends multiple date signals on webpages</br>content marketing statistics</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  answers how long it takes to recover from algorithmic penalty</br>google calm a new language model technology</br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     google
#     <span sty

# %% [markdown]
# ## Building a Knowledge Graph
#
# 1. https://www.analyticsvidhya.com/blog/2019/10/how-to-build-knowledge-graph-text-using-spacy/
#
# 2. https://www.analyticsvidhya.com/blog/2019/09/introduction-information-extraction-python-spacy/?utm_source=blog&utm_medium=how-to-build-knowledge-graph-text-using-spacy
# 3. https://www.kaggle.com/shivamb/spacy-text-meta-features-knowledge-graphs

# %% [markdown]
# Let’s get the dependency tags

# %%
for tok in doc[:100]:
  print(tok.text, "...", tok.dep_)
# Out:
# ranking ... amod
# factors ... nsubj
#
#  ... dep
# webinar ... amod
# lp ... compound
# enterprise ... appos
# seo ... nsubj
# 7 ... nummod
# use ... compound
# cases ... dobj
# to ... aux
# level ... relcl
# up ... prt
# website ... compound
# optimization ... dobj
# with ... prep
# website ... compound
# intelligence ... compound
#
#  ... dep
# enterprise ... compound
# seo ... compound
# guide ... compound
#
#  ... dep
# seo ... compound
# trends ... pobj
# 2023 ... nummod
#
#  ... dep
# search ... compound
# engines ... pobj
#
#  ... dep
# advertise ... conj
#
#  ... dep
# ppc ... compound
# trends ... dative
# 2023 ... nummod
#
#  ... dep
# webinar ... nmod
# lp ... npadvmod
# smarter ... amod
# ads ... dobj
# 5 ... nummod
# cost ... nmod
# efficient ... amod
# ways ... npadvmod
# to ... aux
# get ... relcl
# higher ... amod
# return ... dobj
# on ... prep
# paid ... amod
# media ... compound
#
#  ... dep
# careers ... pobj
#
#  ... dep
# webinar ... amod
# lp ... npadvmod
# how ... advmod
# to ... aux
# predict ... advcl
# your ... poss
# seo ... amod
# success ... dobj
# a ... det
# 5 ... nummod
# step ... compound
# formula ... oprd
# to ... aux
# help ... advcl
# you ... nsubj
# win ... ccomp
#
#  ... dep
# state ... dobj
# of ... prep
# seo ... amod
#
#  ... dep
# contact ... pobj
#
#  ... dep
# seo ... conj
#
#  ... dep
# about ... prep
#
#  ... dep
# webinar ... pobj
# lp ... npadvmod
# 5 ... nummod
# ways ... npadvmod
# to ... aux
# combine ... relcl
# seo ... amod
# sem ... dobj
# for ... prep
# more ... advmod
# effective ... amod
# marketing ... compound
# roi ... compound
#
#  ... dep
# b2b ... compound
# google ... compound
# ad ... compound
# campaigns ... pobj
#
#  ... dep

# %% [markdown]
# The rule can be something like this — extract the subject/object along with its modifiers, compound words and also extract the punctuation marks between them.

# %%
from spacy.matcher import Matcher 
from spacy.tokens import Span 
import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

# %% [markdown]
# To build a knowledge graph, the most important things are the nodes and the edges between them.
#
# The main idea is to go through a sentence and extract the subject and the object as and when they are encountered

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %%
for t in [x for x in new_df["headline"].tolist() if len(x) > 0][:100]:
  print(get_entities(t))
# Out:
# ['', '']
# ['webinar lp enterprise', '7 website intelligence']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['', 'paid  media']
# ['', '']
# ['5 step you', 'seo webinar success']
# ['', 'seo']
# ['', '']
# ['', '']
# ['', '']
# ['', 'effective marketing roi']
# ['', '']
# ['', '']
# ['', 'how google analytics python']
# ['', '']
# ['popular  plugin', 'vulnerability']
# ['', '']
# ['', 'updates  2023']
# ['chief  lists', '3  2023']
# ['', '']
# ['youtube what', 'viral  2023']
# ['', 'social media strategy']
# ['google', 'structured data guidance']
# ['meta', 'eu privacy law violations']
# ['', 'how  slack']
# ['', 'ideas']
# ['', 'reportedly microsoft march']
# ['', '']
# ['', '']
# ['', 'ahead sem review']
# ['google', 'multiple date webpages']
# ['', '']
# ['long google it', 'algorithmic  penalty']
# ['google', 'new language model technology']
# ['google search patents', '']
# ['', '']
# ['google patents', 'always  search']
# ['', '']
# ['google patent interpret', '']
# ['', '']
# ['how  t', 'google patents']
# ['', '']
# ['', 'latest interest february']
# ['', 'latest google interest']
# ['', '']
# ['', 'generic google ratings']
# ['', 'latest interest march']
# ['', '']
# ['rewriting google queries', '']
# ['', 'seo google podcast']
# ['', '']
# ['', '']
# ['', '']
# ['', '']
# ['google query completions', '']
# ['google', 'new know patent']
# ['google patents', 'ranking  factor']
# ['', '']
# ['', '']
# ['chatgpts popularity', '29 billion']
# ['', 'social media marketing 2023']
# ['', '']
# ['social media manager', '']
# ['', '']
# ['', '']
# ['', 'technical canary seo']
# ['', 'seo']
# ['keyword mapping beginners', '']
# ['', '']
# ['', 'how  ecommerce']
# ['how  google', 'site']
# ['apple ad network', 'new  opportunity']
# ['', 'microsoft word powerpoint outlook']
# ['', '']
# ['early sej case', 'part']
# ['', 'quickly forms microsoft word']
# ['', '']
# ['advertisers', 'redundant  keywords']
# ['', 'how link building']
# ['', 'how  month']
# ['best landing practices', '']
# ['marketing trends', '']
# ['marketing strategies ideas', '']
# ['', 'holiday marketing tips']
# ['', 'link building']
# ['', '']
# ['social  that', 'webinar  recap']
# ['technical seo tips', 'webinar  recap']
# ['local business marketer', '']
# ['social  that', 'you']
# ['', '12 opportunities months']
# ['higher optimize google', 'webinar  recap']
# ['free seo tools ahrefs', '']
# ['', 'wordpress ecommerce website']
# ['microsoft', '10 billion 10 openai']
# ['new partner program you', 'new partner program what']

# %%
entity_pairs = []

for i in tqdm([x for x in new_df["headline"].tolist() if len(x) > 0]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 352/352 [00:02<00:00, 162.65it/s]

# %%
entity_pairs[10:20]
# Out:
# [['', 'seo'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', 'effective marketing roi'],
#  ['', ''],
#  ['', ''],
#  ['', 'how google analytics python'],
#  ['', ''],
#  ['popular  plugin', 'vulnerability']]

# %% [markdown]
# Our hypothesis is that the predicate is actually the main verb in a sentence.

# %%
def get_relation(sent):
    doc = nlp(sent)

  # Matcher class object 
    matcher = Matcher(nlp.vocab)

  #define the pattern 
    pattern = [{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}] 

    matcher.add("matching_1", patterns=[pattern]) 

    matches = matcher(doc)
    k = len(matches) - 1

    span = doc[matches[k][1]:matches[k][2]] 

    return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm([x for x in new_df["headline"].tolist() if len(x) > 0])]
# Out:
# 100%|██████████| 352/352 [00:02<00:00, 150.28it/s]

# %%
entity_pairs[10:20]
# Out:
# [['', 'seo'],
#  ['', ''],
#  ['', ''],
#  ['', ''],
#  ['', 'effective marketing roi'],
#  ['', ''],
#  ['', ''],
#  ['', 'how google analytics python'],
#  ['', ''],
#  ['popular  plugin', 'vulnerability']]

# %%
relations[10:20]
# Out:
# ['state of',
#  'contact',
#  'seo',
#  'about',
#  'lp',
#  'campaigns',
#  'podcast',
#  'access',
#  'algorithm',
#  'patches']

# %%
pd.Series(relations).value_counts()[4:50]
# Out:
# linkedin            5
# webinar             5
# seo                 5
# launches new        4
# podcast             4
# confirms            4
# ads                 4
# patent              4
# updates             3
# marketing           3
# template            3
# brands              3
# announces           3
# patents of          3
# update              3
# tool                3
# factors             3
# examples            3
# lead                2
# report              2
# contact             2
# creators            2
# build               2
# get                 2
# algorithm           2
# want                2
# state of            2
# analysis            2
# lp                  2
# patents             2
# create              2
# funnel              2
# ways                2
# launches            2
# media               2
# statistics          2
# trends              2
# recap               2
# ai                  2
# pubcon              2
# introduces new      2
# answers             2
# openai              2
# explains            1
# build productive    1
# deliver             1
# dtype: int64

# %% [markdown]
# Let's build the knowledge graph

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %% [markdown]
# use only a few important relations to visualize a graph. I will take one relation at a time.

# %%
def display_graph(relation):

  G=nx.from_pandas_edgelist(kg_df[kg_df['edge']==relation], "source", "target", 
                            edge_attr=True, create_using=nx.MultiDiGraph())

  plt.figure(figsize=(5,5))
  pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
  nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
  plt.show()

# %% [markdown]
# Now, when I run ```display_graph("launches")```, I get the graph at the begining of the article.

# %%
display_graph("launches")

# %%
display_graph("introduces new")

# %%
display_graph("explains")

# %%
pd.Series(relations).value_counts()[4:50].to_dict()
# Out:
# {'linkedin': 5,
#  'webinar': 5,
#  'seo': 5,
#  'launches new': 4,
#  'podcast': 4,
#  'confirms': 4,
#  'ads': 4,
#  'patent': 4,
#  'updates': 3,
#  'marketing': 3,
#  'template': 3,
#  'brands': 3,
#  'announces': 3,
#  'patents of': 3,
#  'update': 3,
#  'tool': 3,
#  'factors': 3,
#  'examples': 3,
#  'lead': 2,
#  'report': 2,
#  'contact': 2,
#  'creators': 2,
#  'build': 2,
#  'get': 2,
#  'algorithm': 2,
#  'want': 2,
#  'state of': 2,
#  'analysis': 2,
#  'lp': 2,
#  'patents': 2,
#  'create': 2,
#  'funnel': 2,
#  'ways': 2,
#  'launches': 2,
#  'media': 2,
#  'statistics': 2,
#  'trends': 2,
#  'recap': 2,
#  'ai': 2,
#  'pubcon': 2,
#  'introduces new': 2,
#  'answers': 2,
#  'openai': 2,
#  'explains': 1,
#  'build productive': 1,
#  'deliver': 1}

# %%
relation_list = list(pd.Series(relations).value_counts()[4:50].to_dict().keys())
relation_list
# Out:
# ['linkedin',
#  'webinar',
#  'seo',
#  'launches new',
#  'podcast',
#  'confirms',
#  'ads',
#  'patent',
#  'updates',
#  'marketing',
#  'template',
#  'brands',
#  'announces',
#  'patents of',
#  'update',
#  'tool',
#  'factors',
#  'examples',
#  'lead',
#  'report',
#  'contact',
#  'creators',
#  'build',
#  'get',
#  'algorithm',
#  'want',
#  'state of',
#  'analysis',
#  'lp',
#  'patents',
#  'create',
#  'funnel',
#  'ways',
#  'launches',
#  'media',
#  'statistics',
#  'trends',
#  'recap',
#  'ai',
#  'pubcon',
#  'introduces new',
#  'answers',
#  'openai',
#  'explains',
#  'build productive',
#  'deliver']

# %%
relation_choice = "use"  #@param ['launches', 'is',  'on', 'makes', 'adds', 'improve', 'explains', 'optimize','get','use','update','introduces', 'expands','says','find','are','reveals','introduces new', 'make', 'know' ]

display_graph(relation_choice)
